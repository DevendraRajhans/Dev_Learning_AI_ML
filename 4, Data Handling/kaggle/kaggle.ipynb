# %%
# installing kaggle library
# !pip install kaggle

# %%
# !kaggle --version
# Out:
# Kaggle CLI 2.0.0

# %%
# !kaggle datasets download -d schirmerchad/bostonhoustingmlnd
# Out:
# Dataset URL: https://www.kaggle.com/datasets/schirmerchad/bostonhoustingmlnd
# License(s): CC-BY-NC-SA-4.0
# ...
#   0%|          | 0.00/4.35k [00:00<?, ?B/s]
# 100%|██████████| 4.35k/4.35k [00:00<00:00, 3.70MB/s]

# %%
import zipfile

with zipfile.ZipFile("bostonhoustingmlnd.zip", "r") as z:
    z.extractall()

# %%
import pandas as pd

df = pd.read_csv("housing.csv")
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0
